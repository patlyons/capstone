# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np

# %%
#oscars 1998
URL = 'https://www.oscars.org/oscars/ceremonies/1998' # /{year}

response = requests.get(URL)

soup=bs(response.text)

oscar_soup = soup.findAll('div', attrs={'class':'view-grouping'})

# %%
oscar_98 = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup}, orient = 'index').T.melt(var_name='category', value_name='nominee')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [112], in <cell line: 1>()
# ----> 1 oscar_98 = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup}, orient = 'index').T.melt(var_name='category', value_name='nominee')
#
# Input In [112], in <dictcomp>(.0)
# ----> 1 oscar_98 = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup}, orient = 'index').T.melt(var_name='category', value_name='nominee')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
oscar_soup_new = soup.findAll('span', attrs = {'class' : 'field-content'})
oscar_soup_new
# Out:
# [<span class="field-content">The 70th Academy Awards | <span class="date-display-single">1998</span></span>,
#  <span class="field-content"><div class="social-share clearfix"><span class="share-label">Share </span><a class="social-share-facebook" href="https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.oscars.org%2Foscars%2Fceremonies%2F1998" target="_blank" title="Facebook">Facebook</a><a class="social-share-twitter" href="https://twitter.com/share?url=https%3A%2F%2Fwww.oscars.org%2Foscars%2Fceremonies%2F1998&amp;via=TheAcademy" target="_blank" title="Twitter">Twitter</a></div></span>,
#  <span class="field-content">As Good as It Gets
#  </span>,
#  <span class="field-content"></span>,
#  <span class="field-content">Good Will Hunting
#  </span>,
#  <span class="field-content"></span>,
#  <span class="field-content">The Apostle
#  </span>,
#  <span class="field-content"></span>,
#  <span class="field-content">Ulee's Gold
#  </span>,
#  <span class="field-content"></span>,
# ...

# %%
URL = 'https://www.oscars.org/oscars/ceremonies/1998' # /{year}

response = requests.get(URL)

soup=bs(response.text)


oscar_soup = soup.findAll('div', attrs={'class':'view-grouping'})

oscar = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup}, orient = 'index').T.melt(var_name='category', value_name='nominee')
oscar= oscar.dropna()
oscar
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [114], in <cell line: 10>()
#       5 soup=bs(response.text)
#       8 oscar_soup = soup.findAll('div', attrs={'class':'view-grouping'})
# ---> 10 oscar = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup}, orient = 'index').T.melt(var_name='category', value_name='nominee')
#      11 oscar= oscar.dropna()
#      12 oscar
#
# Input In [114], in <dictcomp>(.0)
#       5 soup=bs(response.text)
#       8 oscar_soup = soup.findAll('div', attrs={'class':'view-grouping'})
# ---> 10 oscar = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup}, orient = 'index').T.melt(var_name='category', value_name='nominee')
#      11 oscar= oscar.dropna()
#      12 oscar
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
URL = 'https://www.oscars.org/oscars/ceremonies/1998' # /{year}

response = requests.get(URL)

soup=bs(response.text)

# %%
soup

# %%
oscar_soup = soup.findAll('div', attrs={'class':'view-grouping'})

# %%
oscar_soup
# Out:
# [<div class="view-grouping"><div class="view-grouping-header"><h2>Actor in a Leading Role</h2></div><div class="view-grouping-content"> <h3><span class="golden-text">Winner</span></h3>
#  <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#  <div class="views-field views-field-field-actor-name"> <h4 class="field-content">Jack Nicholson</h4> </div>
#  <div class="views-field views-field-title"> <span class="field-content">As Good as It Gets
#  </span> </div>
#  <div class="views-field views-field-edit-node"> <span class="field-content"></span> </div> </div>
#  <h3>Nominees</h3>
#  <div class="views-row views-row-1 views-row-odd views-row-first">
#  <div class="views-field views-field-field-actor-name"> <h4 class="field-content">Matt Damon</h4> </div>
#  <div class="views-field views-field-title"> <span class="field-content">Good Will Hunting
#  </span> </div>
# ...

# %%
[x.find('h2').text for x in oscar_soup if x.find('h2')]
# Out:
# ['Actor in a Leading Role',
#  'Actor in a Supporting Role',
#  'Actress in a Leading Role',
#  'Actress in a Supporting Role',
#  'Art Direction',
#  'Cinematography',
#  'Costume Design',
#  'Directing',
#  'Documentary (Feature)',
#  'Documentary (Short Subject)',
#  'Film Editing',
#  'Foreign Language Film',
#  'Makeup',
#  'Music (Original Dramatic Score)',
#  'Music (Original Musical or Comedy Score)',
#  'Music (Original Song)',
#  'Best Picture',
#  'Short Film (Animated)',
#  'Short Film (Live Action)',
#  'Sound',
#  'Sound Effects Editing',
#  'Visual Effects',
#  'Writing (Screenplay Based on Material Previously Produced or Published)',
#  'Writing (Screenplay Written Directly for the Screen)']

# %%
[x.find('span').text for x in oscar_soup if x.find('span')]
# Out:
# ['Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '2 Nominations',
#  '1 Nomination',
#  '1 Nomination',
#  '4 Nominations',
#  '2 Nominations',
#  '1 Nomination',
#  '7 Nominations, 2 Wins',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '3 Nominations',
#  '1 Win, 1 Nomination',
#  '1 Win, 1 Nomination',
#  '1 Nomination',
#  '2 Nominations',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '1 Nomination',
#  '4 Nominations, 1 Win',
#  '1 Nomination',
#  '1 Nomination',
# ...

# %%
oscar_soup2 = soup.findAll('div', attrs={'class':'views-field views-field-title'})

# %%
oscar_soup2
# Out:
# [<div class="views-field views-field-title"> <span class="field-content">The 70th Academy Awards | <span class="date-display-single">1998</span></span> </div>,
#  <div class="views-field views-field-title"> <span class="field-content">As Good as It Gets
#  </span> </div>,
#  <div class="views-field views-field-title"> <span class="field-content">Good Will Hunting
#  </span> </div>,
#  <div class="views-field views-field-title"> <span class="field-content">The Apostle
#  </span> </div>,
#  <div class="views-field views-field-title"> <span class="field-content">Ulee's Gold
#  </span> </div>,
#  <div class="views-field views-field-title"> <span class="field-content">Wag the Dog
#  </span> </div>,
#  <div class="views-field views-field-title"> <span class="field-content">Good Will Hunting
#  </span> </div>,
#  <div class="views-field views-field-title"> <span class="field-content">Jackie Brown
#  </span> </div>,
# ...

# %%
[x.find('span').text for x in oscar_soup2 if x.find('span')]
# Out:
# ['The 70th Academy Awards | 1998',
#  'As Good as It Gets\n',
#  'Good Will Hunting\n',
#  'The Apostle\n',
#  "Ulee's Gold\n",
#  'Wag the Dog\n',
#  'Good Will Hunting\n',
#  'Jackie Brown\n',
#  'Amistad\n',
#  'As Good as It Gets\n',
#  'Boogie Nights\n',
#  'As Good as It Gets\n',
#  'The Wings of the Dove\n',
#  'Afterglow\n',
#  'Mrs. Brown\n',
#  'Titanic\n',
#  'L.A. Confidential\n',
#  'In & Out\n',
#  'Good Will Hunting\n',
#  'Boogie Nights\n',
#  'Titanic\n',
#  'Art Direction: Peter Lamont; Set Decoration: Michael Ford\n',
#  'Art Direction: Jan Roelfs; Set Decoration: Nancy Nye\n',
#  'Art Direction: Dante Ferretti; Set Decoration: Francesca Lo Schiavo\n',
#  'Art Direction: Jeannine Oppewall; Set Decoration: Jay R. Hart\n',
#  'Art Direction: Bo Welch; Set Decoration: Cheryl Carasik\n',
#  'Russell Carpenter\n',
#  'Janusz Kaminski\n',
#  'Roger Deakins\n',
#  'Dante Spinotti\n',
#  'Eduardo Serra\n',
#  'Deborah L. Scott\n',
#  'Ruth E. Carter\n',
# ...

# %%
x.findAll('span', attrs = {'class':'field-content'})
# Out:
# [<span class="field-content">As Good as It Gets
#  </span>,
#  <span class="field-content"></span>,
#  <span class="field-content">Good Will Hunting
#  </span>,
#  <span class="field-content"></span>,
#  <span class="field-content">The Apostle
#  </span>,
#  <span class="field-content"></span>,
#  <span class="field-content">Ulee's Gold
#  </span>,
#  <span class="field-content"></span>,
#  <span class="field-content">Wag the Dog
#  </span>,
#  <span class="field-content"></span>]

# %%
oscar_soup3 = soup.findAll('div', attrs={'class':'view-grouping'})

oscar_soup3
# Out:
# [<div class="view-grouping"><div class="view-grouping-header"><h2>Actor in a Leading Role</h2></div><div class="view-grouping-content"> <h3><span class="golden-text">Winner</span></h3>
#  <div class="views-row views-row-1 views-row-odd views-row-first views-row-last">
#  <div class="views-field views-field-field-actor-name"> <h4 class="field-content">Jack Nicholson</h4> </div>
#  <div class="views-field views-field-title"> <span class="field-content">As Good as It Gets
#  </span> </div>
#  <div class="views-field views-field-edit-node"> <span class="field-content"></span> </div> </div>
#  <h3>Nominees</h3>
#  <div class="views-row views-row-1 views-row-odd views-row-first">
#  <div class="views-field views-field-field-actor-name"> <h4 class="field-content">Matt Damon</h4> </div>
#  <div class="views-field views-field-title"> <span class="field-content">Good Will Hunting
#  </span> </div>
# ...

# %%
dict = {}
for group in oscar_soup3: 
    try: 
        
        dict[group.find('h2').text] = [entry.text.strip() for entry in group.findAll('div', attrs={'class':'views-field-title'})]
    except:
        pass
    #print(group.find('div', attrs={'class':'views-field views-field-title'}).find('span', {'class' : 'field-content' }).text)
    #print([entry.text for entry in group.findAll('div', attrs={'class':'views-field-title'})])

# %%
oscars_98 = pd.DataFrame.from_dict(dict, orient = 'index').T
oscars_98['year'] = 1998
oscars98_df = oscars_98[['Writing (Screenplay Written Directly for the Screen)', 'year']]
oscars98_df
#oscars98_df.drop[1:4]
# Out:
#   Writing (Screenplay Written Directly for the Screen)  year
# 0                            Ben Affleck, Matt Damon    1998
# 1  Screenplay by Mark Andrus, James L. Brooks;  S...    1998
# 2                               Paul Thomas Anderson    1998
# 3                                        Woody Allen    1998
# 4                                      Simon Beaufoy    1998

# %%
book = pd.read_csv(r'../data/Book1.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [126], in <cell line: 1>()
# ----> 1 book = pd.read_csv(r'../data/Book1.csv')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
import re

# %%
name = 'Ben Affleck'
name_regex = re.compile(name)
year = 1998
actor_dict = {}

# %%
soup(text = name_regex)
# Out:
# ['Matt Damon and Ben Affleck ',
#  'Ben Affleck, Matt Damon\n',
#  ' Writing (Screenplay Written Directly for the Screen) - Ben Affleck, Matt Damon']

# %%
actor_dict[name] = {year: soup(text = name_regex)}

# %%
actor_dict
# Out:
# {'Ben Affleck': {1998: ['Matt Damon and Ben Affleck ',
#    'Ben Affleck, Matt Damon\n',
#    ' Writing (Screenplay Written Directly for the Screen) - Ben Affleck, Matt Damon']}}

# %%
name = 'Ben Affleck'
name_regex = re.compile(name)
year = 1998
actor_dict = {}
soup(text = name_regex)
actor_dict[name] = {year: soup(text = name_regex)}
actor_dict
# Out:
# {'Ben Affleck': {1998: ['Matt Damon and Ben Affleck ',
#    'Ben Affleck, Matt Damon\n',
#    ' Writing (Screenplay Written Directly for the Screen) - Ben Affleck, Matt Damon']}}

# %%
URL2 = 'https://www.oscars.org/oscars/ceremonies/198'


for num in range (0,10):
    new_url = URL2 +str(num)
    response = requests.get(new_url)
    soup = bs(response.text)
    
name = 'Ben Affleck'
name_regex = re.compile(name)
year = 1998
actor_dict = {}
soup(text = name_regex)
actor_dict[name] = {year: soup(text = name_regex)}
actor_dict
# Out:
# {'Ben Affleck': {1998: []}}

# %%
actor_dict
# Out:
# {'Ben Affleck': {1998: []}}

# %%
URL2 = 'https://www.oscars.org/oscars/ceremonies/198'


for num in range (0,10):
    new_url = URL2 +str(num)
    response = requests.get(new_url)
    soup = bs(response.text)
    
name = 'Ben Affleck'
name_regex = re.compile(name)
year = 1998
actor_dict = {}
soup(text = name_regex)
actor_dict[name] = {year: soup(text = name_regex)}
actor_dict
# Out:
# {'Ben Affleck': {1998: []}}

# %%
actor_dict
# Out:
# {'Ben Affleck': {1998: []}}
