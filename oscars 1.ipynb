# %%
import requests
from bs4 import BeautifulSoup as bs
import pandas as pd
import numpy as np

#URL for list of all oscar nominees over all years
URL = 'https://www.oscars.org/oscars/ceremonies' # /{year}
#get response
response = requests.get(URL)
#make it into a soup
soup=bs(response.text)

#create soup for nominees
oscar_soup = soup.findAll('div', attrs={'class':'view-grouping'})

oscar_2022 = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup},
                                      orient = 'index').T.melt(var_name='category', value_name='nominee')
oscar_2022 = oscar_2022.dropna()
oscar_2022['year'] = 2022
oscar_2022
# Out:
#                           category                        nominee  year
# 0          Actor in a Leading Role                     Will Smith  2022
# 1          Actor in a Leading Role                  Javier Bardem  2022
# 2          Actor in a Leading Role           Benedict Cumberbatch  2022
# 3          Actor in a Leading Role                Andrew Garfield  2022
# 4          Actor in a Leading Role              Denzel Washington  2022
# ..                             ...                            ...   ...
# 220  Writing (Original Screenplay)                        Belfast  2022
# 221  Writing (Original Screenplay)                  Don't Look Up  2022
# 222  Writing (Original Screenplay)                   King Richard  2022
# 223  Writing (Original Screenplay)                 Licorice Pizza  2022
# 224  Writing (Original Screenplay)  The Worst Person in the World  2022
#
# [120 rows x 3 columns]

# %%
#URL for list of all oscar nominees over all years
URL = 'https://www.oscars.org/oscars/ceremonies/1998' # /{year}
#get response
response = requests.get(URL)
#make it into a soup
soup=bs(response.text)

#create soup for nominees
oscar_soup = soup.findAll('div', attrs={'class':'view-grouping-header'})

# %%
oscar_soup
# Out:
# [<div class="view-grouping-header"><h2>Actor in a Leading Role</h2></div>,
#  <div class="view-grouping-header"><h2>Actor in a Supporting Role</h2></div>,
#  <div class="view-grouping-header"><h2>Actress in a Leading Role</h2></div>,
#  <div class="view-grouping-header"><h2>Actress in a Supporting Role</h2></div>,
#  <div class="view-grouping-header"><h2>Art Direction</h2></div>,
#  <div class="view-grouping-header"><h2>Cinematography</h2></div>,
#  <div class="view-grouping-header"><h2>Costume Design</h2></div>,
#  <div class="view-grouping-header"><h2>Directing</h2></div>,
#  <div class="view-grouping-header"><h2>Documentary (Feature)</h2></div>,
#  <div class="view-grouping-header"><h2>Documentary (Short Subject)</h2></div>,
#  <div class="view-grouping-header"><h2>Film Editing</h2></div>,
#  <div class="view-grouping-header"><h2>Foreign Language Film</h2></div>,
#  <div class="view-grouping-header"><h2>Makeup</h2></div>,
# ...

# %%
oscar_2022 = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup}, orient = 'index').T.melt(var_name='category', value_name='nominee')
oscar_2022 = oscar_2022.dropna()
oscar_2022['year'] = 1998
oscar_2022
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 oscar_2022 = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup}, orient = 'index').T.melt(var_name='category', value_name='nominee')
#       2 oscar_2022 = oscar_2022.dropna()
#       3 oscar_2022['year'] = 1998
#
# Input In [11], in <dictcomp>(.0)
# ----> 1 oscar_2022 = pd.DataFrame().from_dict({x.find('h2').text: [y.text for y in x.findAll('h4')] for x in oscar_soup}, orient = 'index').T.melt(var_name='category', value_name='nominee')
#       2 oscar_2022 = oscar_2022.dropna()
#       3 oscar_2022['year'] = 1998
#
# AttributeError: 'NoneType' object has no attribute 'text'
