# %%
import requests
import pandas as pd
import re
from bs4 import BeautifulSoup as bs

# %%
URL = 'https://awardsdatabase.oscars.org/Search/Nominations?nomineeId=3295&view=1-Nominee-Alpha'

# %%
response = requests.get(URL)

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <meta name="title" content="The Academy Awards Database" />\r\n    <meta name="description" content="The Official Academy Awards Database containing records of past Academy Award winners and nominees" />\r\n    <meta name="keywords" content="Award database, Oscar database, Oscars database, Academy Award winner, Academy Award winners, Academy Award nominee, Academy Award nominees, Academy Awards facts, Academy Awards statistics, Academy Awards stats, Oscar winner, Oscar winners, Oscar nominee, Oscar nominees, Oscar facts, Oscar statistics, Oscar stats" />\r\n    <meta name="copyright" content="Copyright (C) 2022 Academy of Motion Picture Arts and Sciences">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1.0 maximum-scale=1.0, user-scalable=no">\r\n    <meta http-equiv="Content-Type" content="text/html" charset="utf-8" />    \r\n    <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />\r\n    <meta http-equ
# ...

# %%
soup = BS(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="The Academy Awards Database" name="title"/>
# <meta content="The Official Academy Awards Database containing records of past Academy Award winners and nominees" name="description"/>
# <meta content="Award database, Oscar database, Oscars database, Academy Award winner, Academy Award winners, Academy Award nominee, Academy Award nominees, Academy Awards facts, Academy Awards statistics, Academy Awards stats, Oscar winner, Oscar winners, Oscar nominee, Oscar nominees, Oscar facts, Oscar statistics, Oscar stats" name="keywords"/>
# <meta content="Copyright (C) 2022 Academy of Motion Picture Arts and Sciences" name="copyright"/>
# <meta content="width=device-width, initial-scale=1.0 maximum-scale=1.0, user-scalable=no" name="viewport"/>
# <meta charset="utf-8" content="text/html" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <meta content="no-cache" http-equiv="Cache-Control"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta content="The Academy Awards Database" name="title"/>
#   <meta content="The Official Academy Awards Database containing records of past Academy Award winners and nominees" name="description"/>
#   <meta content="Award database, Oscar database, Oscars database, Academy Award winner, Academy Award winners, Academy Award nominee, Academy Award nominees, Academy Awards facts, Academy Awards statistics, Academy Awards stats, Oscar winner, Oscar winners, Oscar nominee, Oscar nominees, Oscar facts, Oscar statistics, Oscar stats" name="keywords"/>
#   <meta content="Copyright (C) 2022 Academy of Motion Picture Arts and Sciences" name="copyright"/>
#   <meta content="width=device-width, initial-scale=1.0 maximum-scale=1.0, user-scalable=no" name="viewport"/>
#   <meta charset="utf-8" content="text/html" http-equiv="Content-Type"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# ...

# %%
mk1_num_soup = soup.findAll('div', attrs = {'class' : 'result-group-header'})
mk1_num_soup
# Out:
# []

# %%
{x.find('h2').text: [y.text for y in x.findAll('h4')] for x in soup}
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 {x.find('h2').text: [y.text for y in x.findAll('h4')] for x in soup}
#
# Input In [30], in <dictcomp>(.0)
# ----> 1 {x.find('h2').text: [y.text for y in x.findAll('h4')] for x in soup}
#
# AttributeError: 'int' object has no attribute 'text'

# %%
URL_gc = 'https://www.imdb.com/title/tt0118688/'

response = requests.get(URL_gc)

type(response)

response.status_code

response.text

soup = BS(response.content) soup

print(soup.prettify())

# %%
URL = 'https://awardsdatabase.oscars.org/Search/Nominations?nomineeId=3295&view=1-Nominee-Alpha'

# %%
response = requests.get(URL)

# %%
mk_awards_cat = []
mk_awards_years = []
mk_awards = []
outcome_list = []

URL_mk = 'https://www.imdb.com/name/nm0000474/awards'


new_url = URL_mk
response = requests.get(URL_mk)
soup = bs(response.content)
    
mk_awards_cat = soup.findAll('h3')[1 :81]
    
mk_award_year = soup.findAll('td', attrs = {'class' : 'award_year'})
mk_year_list = []
for i in mk_award_year:
    mk_year_list.append (i.text)
    
ba = []
a_year =[]

for years in mk_year_list:
    x = years.split(' ')
    ba.append(x[0])
    a_year.append(x[1])
 
        
the_year = []
nonsense =[]

for years in a_year:
    x = years.split('\n')
    the_year.append(x[0])
    nonsense.append(x[1])
        
mk_awards = soup.findAll('span', attrs = {'class' : 'award_category'})
    
    
mk_award_outcome = soup.findAll('td', attrs = {'class' : 'award_outcome'})

mk_award_outcome1 = soup.findAll('b')
outcome_list = []
for i in mk_award_outcome1:
    outcome_list.append (i.text)

# %%
len(outcome_list)
# Out:
# 115

# %%
len(the_year)
# Out:
# 111

# %%
outcome_list
# Out:
# ['Nominee',
#  'Nominee',
#  'Nominee',
#  'Nominee',
#  'Winner',
#  'Winner',
#  'Nominee',
#  'Nominee',
#  'Nominee',
#  'Nominee',
#  'Nominee',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Nominee',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Nominee',
#  'Nominee',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Nominee',
#  'Nominee',
#  'Nominee',
#  'Nominee',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Winner',
#  'Nominee',
#  'Nominee',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
#  'Winner',
# ...

# %%
mk_awards
# Out:
# [<span class="award_category">Oscar</span>,
#  <span class="award_category">Primetime Emmy</span>,
#  <span class="award_category">Primetime Emmy</span>,
#  <span class="award_category">BAFTA Film Award</span>,
#  <span class="award_category">AACTA International Award</span>,
#  <span class="award_category">Movies for Grownups Award</span>,
#  <span class="award_category">Movies for Grownups Award</span>,
#  <span class="award_category">Movies for Grownups Award</span>,
#  <span class="award_category">Movies for Grownups Award</span>,
#  <span class="award_category">Saturn Award</span>,
#  <span class="award_category">Saturn Award</span>,
#  <span class="award_category">Saturn Award</span>,
#  <span class="award_category">EDA Award</span>,
#  <span class="award_category">American Comedy Award</span>,
#  <span class="award_category">ACCA</span>,
#  <span class="award_category">ACCA</span>,
#  <span class="award_category">BOFCA Award</span>,
# ...
